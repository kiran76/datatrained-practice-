# %% [markdown]
# # ADVERTISING SALES CHANNEL PROBLEM

# %% [markdown]
# # Data Description

# %% [markdown]
# Sales Channel Prediction Case Study
#
# When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales generated from all the sales channel.

# %% [markdown]
# # Importing Required Liabraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the Dataset:

# %%
df=pd.read_csv("ascp.csv")

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# 19           20  147.3   23.9       19.1   14.6
# 20           21  218.4   27.7       53.4   18.0
# 21           22  237.4    5.1       23.5   12.5
# 22           23   13.2   15.9       49.6    5.6
# 23           24  228.3   16.9       26.2   15.5
# 24           25   62.3   12.6       18.3    9.7
# 25           26  262.9    3.5       19.5   12.0
# 26           27  142.9   29.3       12.6   15.0
# 27           28  240.1   16.7       22.9   15.9
# 28           29  248.8   27.1       22.9   18.9
# 29           30   70.6   16.0       40.8   10.5
# 30           31  292.9   28.3       43.2   21.4
# 31           32  112.9   17.4       38.6   11.9
# 32           33   97.2    1.5       30.0    9.6
# 33           34  265.6   20.0        0.3   17.4
# 34           35   95.7    1.4        7.4    9.5
# 35           36  290.7    4.1        8.5   12.8
# 36           37  266.9   43.8        5.0   25.4
# 37           38   74.7   49.4       45.7   14.7
# 38           39   43.1   26.7       35.1   10.1
# 39           40  228.0   37.7       32.0   21.5
# 40           41  202.5   22.3       31.6   16.6
# 41           42  177.0   33.4       38.7   17.1
# 42           43  293.6   27.7        1.8   20.7
# 43           44  206.9    8.4       26.4   12.9
# 44           45   25.1   25.7       43.3    8.5
# 45           46  175.1   22.5       31.5   14.9
# 46           47   89.7    9.9       35.7   10.6
# 47           48  239.9   41.5       18.5   23.2
# 48           49  227.2   15.8       49.9   14.8
# 49           50   66.9   11.7       36.8    9.7
# 50           51  199.8    3.1       34.6   11.4
# 51           52  100.4    9.6        3.6   10.7
# 52           53  216.4   41.7       39.6   22.6
# 53           54  182.6   46.2       58.7   21.2
# 54           55  262.7   28.8       15.9   20.2
# 55           56  198.9   49.4       60.0   23.7
# 56           57    7.3   28.1       41.4    5.5
# 57           58  136.2   19.2       16.6   13.2
# 58           59  210.8   49.6       37.7   23.8
# 59           60  210.7   29.5        9.3   18.4
# 60           61   53.5    2.0       21.4    8.1
# 61           62  261.3   42.7       54.7   24.2
# 62           63  239.3   15.5       27.3   15.7
# 63           64  102.7   29.6        8.4   14.0
# 64           65  131.1   42.8       28.9   18.0
# 65           66   69.0    9.3        0.9    9.3
# 66           67   31.5   24.6        2.2    9.5
# 67           68  139.3   14.5       10.2   13.4
# 68           69  237.4   27.5       11.0   18.9
# 69           70  216.8   43.9       27.2   22.3
# 70           71  199.1   30.6       38.7   18.3
# 71           72  109.8   14.3       31.7   12.4
# 72           73   26.8   33.0       19.3    8.8
# 73           74  129.4    5.7       31.3   11.0
# 74           75  213.4   24.6       13.1   17.0
# 75           76   16.9   43.7       89.4    8.7
# 76           77   27.5    1.6       20.7    6.9
# 77           78  120.5   28.5       14.2   14.2
# 78           79    5.4   29.9        9.4    5.3
# 79           80  116.0    7.7       23.1   11.0
# 80           81   76.4   26.7       22.3   11.8
# 81           82  239.8    4.1       36.9   12.3
# 82           83   75.3   20.3       32.5   11.3
# 83           84   68.4   44.5       35.6   13.6
# 84           85  213.5   43.0       33.8   21.7
# 85           86  193.2   18.4       65.7   15.2
# 86           87   76.3   27.5       16.0   12.0
# 87           88  110.7   40.6       63.2   16.0
# 88           89   88.3   25.5       73.4   12.9
# 89           90  109.8   47.8       51.4   16.7
# 90           91  134.3    4.9        9.3   11.2
# 91           92   28.6    1.5       33.0    7.3
# 92           93  217.7   33.5       59.0   19.4
# 93           94  250.9   36.5       72.3   22.2
# 94           95  107.4   14.0       10.9   11.5
# 95           96  163.3   31.6       52.9   16.9
# 96           97  197.6    3.5        5.9   11.7
# 97           98  184.9   21.0       22.0   15.5
# 98           99  289.7   42.3       51.2   25.4
# 99          100  135.2   41.7       45.9   17.2
# 100         101  222.4    4.3       49.8   11.7
# 101         102  296.4   36.3      100.9   23.8
# 102         103  280.2   10.1       21.4   14.8
# 103         104  187.9   17.2       17.9   14.7
# 104         105  238.2   34.3        5.3   20.7
# 105         106  137.9   46.4       59.0   19.2
# 106         107   25.0   11.0       29.7    7.2
# 107         108   90.4    0.3       23.2    8.7
# 108         109   13.1    0.4       25.6    5.3
# 109         110  255.4   26.9        5.5   19.8
# 110         111  225.8    8.2       56.5   13.4
# 111         112  241.7   38.0       23.2   21.8
# 112         113  175.7   15.4        2.4   14.1
# 113         114  209.6   20.6       10.7   15.9
# 114         115   78.2   46.8       34.5   14.6
# 115         116   75.1   35.0       52.7   12.6
# 116         117  139.2   14.3       25.6   12.2
# 117         118   76.4    0.8       14.8    9.4
# 118         119  125.7   36.9       79.2   15.9
# 119         120   19.4   16.0       22.3    6.6
# 120         121  141.3   26.8       46.2   15.5
# 121         122   18.8   21.7       50.4    7.0
# 122         123  224.0    2.4       15.6   11.6
# 123         124  123.1   34.6       12.4   15.2
# 124         125  229.5   32.3       74.2   19.7
# 125         126   87.2   11.8       25.9   10.6
# 126         127    7.8   38.9       50.6    6.6
# 127         128   80.2    0.0        9.2    8.8
# 128         129  220.3   49.0        3.2   24.7
# 129         130   59.6   12.0       43.1    9.7
# 130         131    0.7   39.6        8.7    1.6
# 131         132  265.2    2.9       43.0   12.7
# 132         133    8.4   27.2        2.1    5.7
# 133         134  219.8   33.5       45.1   19.6
# 134         135   36.9   38.6       65.6   10.8
# 135         136   48.3   47.0        8.5   11.6
# 136         137   25.6   39.0        9.3    9.5
# 137         138  273.7   28.9       59.7   20.8
# 138         139   43.0   25.9       20.5    9.6
# 139         140  184.9   43.9        1.7   20.7
# 140         141   73.4   17.0       12.9   10.9
# 141         142  193.7   35.4       75.6   19.2
# 142         143  220.5   33.2       37.9   20.1
# 143         144  104.6    5.7       34.4   10.4
# 144         145   96.2   14.8       38.9   11.4
# 145         146  140.3    1.9        9.0   10.3
# 146         147  240.1    7.3        8.7   13.2
# 147         148  243.2   49.0       44.3   25.4
# 148         149   38.0   40.3       11.9   10.9
# 149         150   44.7   25.8       20.6   10.1
# 150         151  280.7   13.9       37.0   16.1
# 151         152  121.0    8.4       48.7   11.6
# 152         153  197.6   23.3       14.2   16.6
# 153         154  171.3   39.7       37.7   19.0
# 154         155  187.8   21.1        9.5   15.6
# 155         156    4.1   11.6        5.7    3.2
# 156         157   93.9   43.5       50.5   15.3
# 157         158  149.8    1.3       24.3   10.1
# 158         159   11.7   36.9       45.2    7.3
# 159         160  131.7   18.4       34.6   12.9
# 160         161  172.5   18.1       30.7   14.4
# 161         162   85.7   35.8       49.3   13.3
# 162         163  188.4   18.1       25.6   14.9
# 163         164  163.5   36.8        7.4   18.0
# 164         165  117.2   14.7        5.4   11.9
# 165         166  234.5    3.4       84.8   11.9
# 166         167   17.9   37.6       21.6    8.0
# 167         168  206.8    5.2       19.4   12.2
# 168         169  215.4   23.6       57.6   17.1
# 169         170  284.3   10.6        6.4   15.0
# 170         171   50.0   11.6       18.4    8.4
# 171         172  164.5   20.9       47.4   14.5
# 172         173   19.6   20.1       17.0    7.6
# 173         174  168.4    7.1       12.8   11.7
# 174         175  222.4    3.4       13.1   11.5
# 175         176  276.9   48.9       41.8   27.0
# 176         177  248.4   30.2       20.3   20.2
# 177         178  170.2    7.8       35.2   11.7
# 178         179  276.7    2.3       23.7   11.8
# 179         180  165.6   10.0       17.6   12.6
# 180         181  156.6    2.6        8.3   10.5
# 181         182  218.5    5.4       27.4   12.2
# 182         183   56.2    5.7       29.7    8.7
# 183         184  287.6   43.0       71.8   26.2
# 184         185  253.8   21.3       30.0   17.6
# 185         186  205.0   45.1       19.6   22.6
# 186         187  139.5    2.1       26.6   10.3
# 187         188  191.1   28.7       18.2   17.3
# 188         189  286.0   13.9        3.7   15.9
# 189         190   18.7   12.1       23.4    6.7
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# # Checking The columns of the Dataset:

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# # Checking the datatypes of the columns:

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# # Checking Null Values in the DataFrame:

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# # Visualization of the Data:

# %% [markdown]
# Checking the distribution of the continuous value of the float type columns.

# %%
sns.distplot(df['TV'],kde=True)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['radio'],kde=True)
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %%
sns.distplot(df['newspaper'],kde=True)
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %%
sns.distplot(df['sales'],kde=True)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
plt.show()

# %% [markdown]
# Correlation of the columns with the Target columns:

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
plt.show()

# %% [markdown]
# Checking the columns which are positively and negatively correlated with the target columns:

# %%
plt.figure(figsize=(10,5))
df.corr()['sales'].sort_values(ascending=False).drop(['sales']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.894720
# sales         0.407571
# dtype: float64

# %% [markdown]
# # Checking Outliers:

# %%
df['TV'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['radio'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['newspaper'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# we found ouliers in newspaper.

# %% [markdown]
# # Considering the outlier removal

# %%
df.shape
# Out:
# (200, 5)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 16, 101], dtype=int64), array([3, 3], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# 19           20  147.3   23.9       19.1   14.6
# 20           21  218.4   27.7       53.4   18.0
# 21           22  237.4    5.1       23.5   12.5
# 22           23   13.2   15.9       49.6    5.6
# 23           24  228.3   16.9       26.2   15.5
# 24           25   62.3   12.6       18.3    9.7
# 25           26  262.9    3.5       19.5   12.0
# 26           27  142.9   29.3       12.6   15.0
# 27           28  240.1   16.7       22.9   15.9
# 28           29  248.8   27.1       22.9   18.9
# 29           30   70.6   16.0       40.8   10.5
# 30           31  292.9   28.3       43.2   21.4
# 31           32  112.9   17.4       38.6   11.9
# 32           33   97.2    1.5       30.0    9.6
# 33           34  265.6   20.0        0.3   17.4
# 34           35   95.7    1.4        7.4    9.5
# 35           36  290.7    4.1        8.5   12.8
# 36           37  266.9   43.8        5.0   25.4
# 37           38   74.7   49.4       45.7   14.7
# 38           39   43.1   26.7       35.1   10.1
# 39           40  228.0   37.7       32.0   21.5
# 40           41  202.5   22.3       31.6   16.6
# 41           42  177.0   33.4       38.7   17.1
# 42           43  293.6   27.7        1.8   20.7
# 43           44  206.9    8.4       26.4   12.9
# 44           45   25.1   25.7       43.3    8.5
# 45           46  175.1   22.5       31.5   14.9
# 46           47   89.7    9.9       35.7   10.6
# 47           48  239.9   41.5       18.5   23.2
# 48           49  227.2   15.8       49.9   14.8
# 49           50   66.9   11.7       36.8    9.7
# 50           51  199.8    3.1       34.6   11.4
# 51           52  100.4    9.6        3.6   10.7
# 52           53  216.4   41.7       39.6   22.6
# 53           54  182.6   46.2       58.7   21.2
# 54           55  262.7   28.8       15.9   20.2
# 55           56  198.9   49.4       60.0   23.7
# 56           57    7.3   28.1       41.4    5.5
# 57           58  136.2   19.2       16.6   13.2
# 58           59  210.8   49.6       37.7   23.8
# 59           60  210.7   29.5        9.3   18.4
# 60           61   53.5    2.0       21.4    8.1
# 61           62  261.3   42.7       54.7   24.2
# 62           63  239.3   15.5       27.3   15.7
# 63           64  102.7   29.6        8.4   14.0
# 64           65  131.1   42.8       28.9   18.0
# 65           66   69.0    9.3        0.9    9.3
# 66           67   31.5   24.6        2.2    9.5
# 67           68  139.3   14.5       10.2   13.4
# 68           69  237.4   27.5       11.0   18.9
# 69           70  216.8   43.9       27.2   22.3
# 70           71  199.1   30.6       38.7   18.3
# 71           72  109.8   14.3       31.7   12.4
# 72           73   26.8   33.0       19.3    8.8
# 73           74  129.4    5.7       31.3   11.0
# 74           75  213.4   24.6       13.1   17.0
# 75           76   16.9   43.7       89.4    8.7
# 76           77   27.5    1.6       20.7    6.9
# 77           78  120.5   28.5       14.2   14.2
# 78           79    5.4   29.9        9.4    5.3
# 79           80  116.0    7.7       23.1   11.0
# 80           81   76.4   26.7       22.3   11.8
# 81           82  239.8    4.1       36.9   12.3
# 82           83   75.3   20.3       32.5   11.3
# 83           84   68.4   44.5       35.6   13.6
# 84           85  213.5   43.0       33.8   21.7
# 85           86  193.2   18.4       65.7   15.2
# 86           87   76.3   27.5       16.0   12.0
# 87           88  110.7   40.6       63.2   16.0
# 88           89   88.3   25.5       73.4   12.9
# 89           90  109.8   47.8       51.4   16.7
# 90           91  134.3    4.9        9.3   11.2
# 91           92   28.6    1.5       33.0    7.3
# 92           93  217.7   33.5       59.0   19.4
# 93           94  250.9   36.5       72.3   22.2
# 94           95  107.4   14.0       10.9   11.5
# 95           96  163.3   31.6       52.9   16.9
# 96           97  197.6    3.5        5.9   11.7
# 97           98  184.9   21.0       22.0   15.5
# 98           99  289.7   42.3       51.2   25.4
# 99          100  135.2   41.7       45.9   17.2
# 100         101  222.4    4.3       49.8   11.7
# 102         103  280.2   10.1       21.4   14.8
# 103         104  187.9   17.2       17.9   14.7
# 104         105  238.2   34.3        5.3   20.7
# 105         106  137.9   46.4       59.0   19.2
# 106         107   25.0   11.0       29.7    7.2
# 107         108   90.4    0.3       23.2    8.7
# 108         109   13.1    0.4       25.6    5.3
# 109         110  255.4   26.9        5.5   19.8
# 110         111  225.8    8.2       56.5   13.4
# 111         112  241.7   38.0       23.2   21.8
# 112         113  175.7   15.4        2.4   14.1
# 113         114  209.6   20.6       10.7   15.9
# 114         115   78.2   46.8       34.5   14.6
# 115         116   75.1   35.0       52.7   12.6
# 116         117  139.2   14.3       25.6   12.2
# 117         118   76.4    0.8       14.8    9.4
# 118         119  125.7   36.9       79.2   15.9
# 119         120   19.4   16.0       22.3    6.6
# 120         121  141.3   26.8       46.2   15.5
# 121         122   18.8   21.7       50.4    7.0
# 122         123  224.0    2.4       15.6   11.6
# 123         124  123.1   34.6       12.4   15.2
# 124         125  229.5   32.3       74.2   19.7
# 125         126   87.2   11.8       25.9   10.6
# 126         127    7.8   38.9       50.6    6.6
# 127         128   80.2    0.0        9.2    8.8
# 128         129  220.3   49.0        3.2   24.7
# 129         130   59.6   12.0       43.1    9.7
# 130         131    0.7   39.6        8.7    1.6
# 131         132  265.2    2.9       43.0   12.7
# 132         133    8.4   27.2        2.1    5.7
# 133         134  219.8   33.5       45.1   19.6
# 134         135   36.9   38.6       65.6   10.8
# 135         136   48.3   47.0        8.5   11.6
# 136         137   25.6   39.0        9.3    9.5
# 137         138  273.7   28.9       59.7   20.8
# 138         139   43.0   25.9       20.5    9.6
# 139         140  184.9   43.9        1.7   20.7
# 140         141   73.4   17.0       12.9   10.9
# 141         142  193.7   35.4       75.6   19.2
# 142         143  220.5   33.2       37.9   20.1
# 143         144  104.6    5.7       34.4   10.4
# 144         145   96.2   14.8       38.9   11.4
# 145         146  140.3    1.9        9.0   10.3
# 146         147  240.1    7.3        8.7   13.2
# 147         148  243.2   49.0       44.3   25.4
# 148         149   38.0   40.3       11.9   10.9
# 149         150   44.7   25.8       20.6   10.1
# 150         151  280.7   13.9       37.0   16.1
# 151         152  121.0    8.4       48.7   11.6
# 152         153  197.6   23.3       14.2   16.6
# 153         154  171.3   39.7       37.7   19.0
# 154         155  187.8   21.1        9.5   15.6
# 155         156    4.1   11.6        5.7    3.2
# 156         157   93.9   43.5       50.5   15.3
# 157         158  149.8    1.3       24.3   10.1
# 158         159   11.7   36.9       45.2    7.3
# 159         160  131.7   18.4       34.6   12.9
# 160         161  172.5   18.1       30.7   14.4
# 161         162   85.7   35.8       49.3   13.3
# 162         163  188.4   18.1       25.6   14.9
# 163         164  163.5   36.8        7.4   18.0
# 164         165  117.2   14.7        5.4   11.9
# 165         166  234.5    3.4       84.8   11.9
# 166         167   17.9   37.6       21.6    8.0
# 167         168  206.8    5.2       19.4   12.2
# 168         169  215.4   23.6       57.6   17.1
# 169         170  284.3   10.6        6.4   15.0
# 170         171   50.0   11.6       18.4    8.4
# 171         172  164.5   20.9       47.4   14.5
# 172         173   19.6   20.1       17.0    7.6
# 173         174  168.4    7.1       12.8   11.7
# 174         175  222.4    3.4       13.1   11.5
# 175         176  276.9   48.9       41.8   27.0
# 176         177  248.4   30.2       20.3   20.2
# 177         178  170.2    7.8       35.2   11.7
# 178         179  276.7    2.3       23.7   11.8
# 179         180  165.6   10.0       17.6   12.6
# 180         181  156.6    2.6        8.3   10.5
# 181         182  218.5    5.4       27.4   12.2
# 182         183   56.2    5.7       29.7    8.7
# 183         184  287.6   43.0       71.8   26.2
# 184         185  253.8   21.3       30.0   17.6
# 185         186  205.0   45.1       19.6   22.6
# 186         187  139.5    2.1       26.6   10.3
# 187         188  191.1   28.7       18.2   17.3
# 188         189  286.0   13.9        3.7   15.9
# 189         190   18.7   12.1       23.4    6.7
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df_new_z.shape
# Out:
# (198, 5)

# %%
#percentage loss of data:

# %%
Data_loss=((200-198)/200)*100

# %%
Data_loss
# Out:
# 1.0

# %% [markdown]
# Outlier is Removed

# %% [markdown]
# # Separating the columns into features and target:

# %%
x=df.drop('sales',axis=1)
y=df['sales']

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,300):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i},the training accuracy is:{r2_score(y_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is:{r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is:0.9073274552252846
# At random state 0,the testing accuracy is:0.8564802143279248
#
#
# At random state 1,the training accuracy is:0.8959391993971187
# At random state 1,the testing accuracy is:0.8928781912093181
#
#
# At random state 2,the training accuracy is:0.9152614531156524
# At random state 2,the testing accuracy is:0.7570326409482366
#
#
# At random state 3,the training accuracy is:0.8931443451313652
# At random state 3,the testing accuracy is:0.9134449674582059
#
#
# At random state 4,the training accuracy is:0.8911682084041699
# At random state 4,the testing accuracy is:0.9084934434517353
#
#
# At random state 5,the training accuracy is:0.89570620107301
# At random state 5,the testing accuracy is:0.89851958363058
#
#
# At random state 6,the training accuracy is:0.8915582028345674
# At random state 6,the testing accuracy is:0.921941222913581
#
#
# At random state 7,the training accuracy is:0.8929171093102488
# At random state 7,the testing accuracy is:0.9094946118605033
#
#
# At random state 8,the training accuracy is:0.9089671598668994
# At random state 8,the testing accuracy is:0.8454524606304807
#
#
# At random state 9,the training accuracy is:0.8897879071515497
# At random state 9,the testing accuracy is:0.9254791165935141
#
#
# At random state 10,the training accuracy is:0.9210064755430887
# At random state 10,the testing accuracy is:0.8350889287403332
#
#
# At random state 11,the training accuracy is:0.9111623809104603
# At random state 11,the testing accuracy is:0.8449820092996334
#
#
# At random state 12,the training accuracy is:0.8918075499129059
# At random state 12,the testing accuracy is:0.911000758276677
#
#
# At random state 13,the training accuracy is:0.887016186914774
# At random state 13,the testing accuracy is:0.930587014890429
#
#
# At random state 14,the training accuracy is:0.9086355983008996
# At random state 14,the testing accuracy is:0.8549475163509117
#
#
# At random state 15,the training accuracy is:0.8938079254185115
# At random state 15,the testing accuracy is:0.9055692412310972
#
#
# At random state 16,the training accuracy is:0.8926643673594483
# At random state 16,the testing accuracy is:0.9179051167419227
#
#
# At random state 17,the training accuracy is:0.9116703196823303
# At random state 17,the testing accuracy is:0.8260144163842625
#
#
# At random state 18,the training accuracy is:0.9058537276169787
# At random state 18,the testing accuracy is:0.8692586836034338
#
#
# At random state 19,the training accuracy is:0.8936964884458825
# At random state 19,the testing accuracy is:0.9035293150713194
#
#
# At random state 20,the training accuracy is:0.8940674217997686
# At random state 20,the testing accuracy is:0.9028631545455051
#
#
# At random state 21,the training accuracy is:0.8890540600770627
# At random state 21,the testing accuracy is:0.9146569039385175
#
#
# At random state 22,the training accuracy is:0.8899973381223143
# At random state 22,the testing accuracy is:0.9182082402965808
#
#
# At random state 23,the training accuracy is:0.8921767001074105
# At random state 23,the testing accuracy is:0.9099324713476881
#
#
# At random state 24,the training accuracy is:0.8948669853718487
# At random state 24,the testing accuracy is:0.9031175758867456
#
#
# At random state 25,the training accuracy is:0.901084029469538
# At random state 25,the testing accuracy is:0.8720389628792302
#
#
# At random state 26,the training accuracy is:0.9008142925470226
# At random state 26,the testing accuracy is:0.8660817826604934
#
#
# At random state 27,the training accuracy is:0.8949084508267352
# At random state 27,the testing accuracy is:0.9055839757493602
#
#
# At random state 28,the training accuracy is:0.8997566457323917
# At random state 28,the testing accuracy is:0.882889952375476
#
#
# At random state 29,the training accuracy is:0.8897990754621425
# At random state 29,the testing accuracy is:0.9121642709962423
#
#
# At random state 30,the training accuracy is:0.8935867104133169
# At random state 30,the testing accuracy is:0.9070725716744539
#
#
# At random state 31,the training accuracy is:0.8861151331622692
# At random state 31,the testing accuracy is:0.9274231828872664
#
#
# At random state 32,the training accuracy is:0.9172993061976911
# At random state 32,the testing accuracy is:0.7769624816211903
#
#
# At random state 33,the training accuracy is:0.896294422055296
# At random state 33,the testing accuracy is:0.8938166042095907
#
#
# At random state 34,the training accuracy is:0.8970815554113069
# At random state 34,the testing accuracy is:0.8919648426080481
#
#
# At random state 35,the training accuracy is:0.9149816013369177
# At random state 35,the testing accuracy is:0.786373587730015
#
#
# At random state 36,the training accuracy is:0.8887390025066806
# At random state 36,the testing accuracy is:0.9265569630488937
#
#
# At random state 37,the training accuracy is:0.8998734924150504
# At random state 37,the testing accuracy is:0.883238146412001
#
#
# At random state 38,the training accuracy is:0.8972914103912516
# At random state 38,the testing accuracy is:0.890869613550319
#
#
# At random state 39,the training accuracy is:0.9002556473795614
# At random state 39,the testing accuracy is:0.8690558832908659
#
#
# At random state 40,the training accuracy is:0.9204058033654225
# At random state 40,the testing accuracy is:0.7965905680536841
#
#
# At random state 41,the training accuracy is:0.9006927327079468
# At random state 41,the testing accuracy is:0.882047061468867
#
#
# At random state 42,the training accuracy is:0.8957553000540606
# At random state 42,the testing accuracy is:0.8986489151417082
#
#
# At random state 43,the training accuracy is:0.8886405668646471
# At random state 43,the testing accuracy is:0.9279997802005557
#
#
# At random state 44,the training accuracy is:0.9065906284233083
# At random state 44,the testing accuracy is:0.8309225032852494
#
#
# At random state 45,the training accuracy is:0.8963875424029035
# At random state 45,the testing accuracy is:0.8915316806090343
#
#
# At random state 46,the training accuracy is:0.9036235036433334
# At random state 46,the testing accuracy is:0.8503383755246359
#
#
# At random state 47,the training accuracy is:0.8988386546103042
# At random state 47,the testing accuracy is:0.8849834045904889
#
#
# At random state 48,the training accuracy is:0.890542166403924
# At random state 48,the testing accuracy is:0.9189262097926163
#
#
# At random state 49,the training accuracy is:0.913865852180709
# At random state 49,the testing accuracy is:0.8231216329494812
#
#
# At random state 50,the training accuracy is:0.9013718398317787
# At random state 50,the testing accuracy is:0.8476464379397717
#
#
# At random state 51,the training accuracy is:0.8936175989328148
# At random state 51,the testing accuracy is:0.9076546711720634
#
#
# At random state 52,the training accuracy is:0.9018604295382086
# At random state 52,the testing accuracy is:0.8807089729330375
#
#
# At random state 53,the training accuracy is:0.888857938922339
# At random state 53,the testing accuracy is:0.9251773581549693
#
#
# At random state 54,the training accuracy is:0.8920887237166686
# At random state 54,the testing accuracy is:0.9172149618279113
#
#
# At random state 55,the training accuracy is:0.894930160761274
# At random state 55,the testing accuracy is:0.8978864477773827
#
#
# At random state 56,the training accuracy is:0.8989201587327643
# At random state 56,the testing accuracy is:0.8882246349534562
#
#
# At random state 57,the training accuracy is:0.8825879766148067
# At random state 57,the testing accuracy is:0.9408099432427625
#
#
# At random state 58,the training accuracy is:0.9127355018257423
# At random state 58,the testing accuracy is:0.8401442189987403
#
#
# At random state 59,the training accuracy is:0.8893758445368163
# At random state 59,the testing accuracy is:0.92502470552889
#
#
# At random state 60,the training accuracy is:0.8929488169971975
# At random state 60,the testing accuracy is:0.9074416119003319
#
#
# At random state 61,the training accuracy is:0.8995558396715964
# At random state 61,the testing accuracy is:0.878101642882558
#
#
# At random state 62,the training accuracy is:0.9120188082159291
# At random state 62,the testing accuracy is:0.8418326614272957
#
#
# At random state 63,the training accuracy is:0.8951057681539462
# At random state 63,the testing accuracy is:0.9005058624602784
#
#
# At random state 64,the training accuracy is:0.8977795664080803
# At random state 64,the testing accuracy is:0.881799559582723
#
#
# At random state 65,the training accuracy is:0.8969891176837769
# At random state 65,the testing accuracy is:0.8942556589953751
#
#
# At random state 66,the training accuracy is:0.8992060099166295
# At random state 66,the testing accuracy is:0.8838295132236418
#
#
# At random state 67,the training accuracy is:0.8995954079489461
# At random state 67,the testing accuracy is:0.8813062371563375
#
#
# At random state 68,the training accuracy is:0.9004472797727481
# At random state 68,the testing accuracy is:0.8669862566176891
#
#
# At random state 69,the training accuracy is:0.8870476050134384
# At random state 69,the testing accuracy is:0.9233095015758521
#
#
# At random state 70,the training accuracy is:0.8862589587247461
# At random state 70,the testing accuracy is:0.9261899619072468
#
#
# At random state 71,the training accuracy is:0.9170792242159567
# At random state 71,the testing accuracy is:0.8214330315197063
#
#
# At random state 72,the training accuracy is:0.8939630309765105
# At random state 72,the testing accuracy is:0.9063814288042916
#
#
# At random state 73,the training accuracy is:0.9081745525874727
# At random state 73,the testing accuracy is:0.8382456514164831
#
#
# At random state 74,the training accuracy is:0.8980451797105264
# At random state 74,the testing accuracy is:0.8802918295913446
#
#
# At random state 75,the training accuracy is:0.8944097316106918
# At random state 75,the testing accuracy is:0.9074740863261651
#
#
# At random state 76,the training accuracy is:0.9092071576699313
# At random state 76,the testing accuracy is:0.7531289748171519
#
#
# At random state 77,the training accuracy is:0.8859821552154191
# At random state 77,the testing accuracy is:0.937956975915543
#
#
# At random state 78,the training accuracy is:0.8957614044756782
# At random state 78,the testing accuracy is:0.9027962436962178
#
#
# At random state 79,the training accuracy is:0.8918809749821501
# At random state 79,the testing accuracy is:0.9039590138288892
#
#
# At random state 80,the training accuracy is:0.9169729628077916
# At random state 80,the testing accuracy is:0.8002879936768355
#
#
# At random state 81,the training accuracy is:0.9035712487248864
# At random state 81,the testing accuracy is:0.8609698767855934
#
#
# At random state 82,the training accuracy is:0.9154275126468338
# At random state 82,the testing accuracy is:0.8013214526563002
#
#
# At random state 83,the training accuracy is:0.8842230653829803
# At random state 83,the testing accuracy is:0.9365331832976409
#
#
# At random state 84,the training accuracy is:0.8954723130793452
# At random state 84,the testing accuracy is:0.8982625547501828
#
#
# At random state 85,the training accuracy is:0.9086556153894079
# At random state 85,the testing accuracy is:0.8439750044569612
#
#
# At random state 86,the training accuracy is:0.8941933141983466
# At random state 86,the testing accuracy is:0.9101136416354886
#
#
# At random state 87,the training accuracy is:0.9120854281966964
# At random state 87,the testing accuracy is:0.7590318344044371
#
#
# At random state 88,the training accuracy is:0.909607024863585
# At random state 88,the testing accuracy is:0.8387190488012206
#
#
# At random state 89,the training accuracy is:0.9007733237783739
# At random state 89,the testing accuracy is:0.8715218402293792
#
#
# At random state 90,the training accuracy is:0.9035155910972225
# At random state 90,the testing accuracy is:0.8470679956762829
#
#
# At random state 91,the training accuracy is:0.8874503790642361
# At random state 91,the testing accuracy is:0.9040620243534965
#
#
# At random state 92,the training accuracy is:0.879228484038034
# At random state 92,the testing accuracy is:0.950983339269277
#
#
# At random state 93,the training accuracy is:0.8934257355566151
# At random state 93,the testing accuracy is:0.9092789029786972
#
#
# At random state 94,the training accuracy is:0.9084405371218475
# At random state 94,the testing accuracy is:0.8559756457570239
#
#
# At random state 95,the training accuracy is:0.8935661522674359
# At random state 95,the testing accuracy is:0.895148309410786
#
#
# At random state 96,the training accuracy is:0.9038616523881903
# At random state 96,the testing accuracy is:0.858009872088536
#
#
# At random state 97,the training accuracy is:0.8906962083562392
# At random state 97,the testing accuracy is:0.9077630204640282
#
#
# At random state 98,the training accuracy is:0.8820113423343214
# At random state 98,the testing accuracy is:0.9393724951506758
#
#
# At random state 99,the training accuracy is:0.8906644266587816
# At random state 99,the testing accuracy is:0.9201416862699034
#
#
# At random state 100,the training accuracy is:0.891560764129048
# At random state 100,the testing accuracy is:0.9184136004105716
#
#
# At random state 101,the training accuracy is:0.8880213132614394
# At random state 101,the testing accuracy is:0.9284717132168754
#
#
# At random state 102,the training accuracy is:0.8930169789676244
# At random state 102,the testing accuracy is:0.9077409503946586
#
#
# At random state 103,the training accuracy is:0.8877803523628486
# At random state 103,the testing accuracy is:0.9317918414066232
#
#
# At random state 104,the training accuracy is:0.9171443168946798
# At random state 104,the testing accuracy is:0.8183131076651275
#
#
# At random state 105,the training accuracy is:0.8896304217439883
# At random state 105,the testing accuracy is:0.9207702068111918
#
#
# At random state 106,the training accuracy is:0.8964069872883923
# At random state 106,the testing accuracy is:0.8890631519613172
#
#
# At random state 107,the training accuracy is:0.8931999696730355
# At random state 107,the testing accuracy is:0.9076337517595119
#
#
# At random state 108,the training accuracy is:0.8976128161540851
# At random state 108,the testing accuracy is:0.8889551188968406
#
#
# At random state 109,the training accuracy is:0.9105559085921455
# At random state 109,the testing accuracy is:0.8609214461430874
#
#
# At random state 110,the training accuracy is:0.8828114089008886
# At random state 110,the testing accuracy is:0.9357141921769534
#
#
# At random state 111,the training accuracy is:0.9112774190623674
# At random state 111,the testing accuracy is:0.8611230870164995
#
#
# At random state 112,the training accuracy is:0.8954701541867378
# At random state 112,the testing accuracy is:0.902697330353968
#
#
# At random state 113,the training accuracy is:0.8906939107105335
# At random state 113,the testing accuracy is:0.9220916025084388
#
#
# At random state 114,the training accuracy is:0.883832912829592
# At random state 114,the testing accuracy is:0.9339934506171427
#
#
# At random state 115,the training accuracy is:0.8863116052389997
# At random state 115,the testing accuracy is:0.9216625945522067
#
#
# At random state 116,the training accuracy is:0.90198203211419
# At random state 116,the testing accuracy is:0.8758171132643975
#
#
# At random state 117,the training accuracy is:0.8853877128863069
# At random state 117,the testing accuracy is:0.9294013031911124
#
#
# At random state 118,the training accuracy is:0.8943719717809722
# At random state 118,the testing accuracy is:0.9077414451048316
#
#
# At random state 119,the training accuracy is:0.9167766380186102
# At random state 119,the testing accuracy is:0.7973069537361156
#
#
# At random state 120,the training accuracy is:0.9098607279294674
# At random state 120,the testing accuracy is:0.8346668527296213
#
#
# At random state 121,the training accuracy is:0.8936679272362575
# At random state 121,the testing accuracy is:0.9043912406937376
#
#
# At random state 122,the training accuracy is:0.9183813858005966
# At random state 122,the testing accuracy is:0.7921999424166526
#
#
# At random state 123,the training accuracy is:0.8875152814510524
# At random state 123,the testing accuracy is:0.928483263093544
#
#
# At random state 124,the training accuracy is:0.8980042134150305
# At random state 124,the testing accuracy is:0.8822646467403392
#
#
# At random state 125,the training accuracy is:0.8932980581897926
# At random state 125,the testing accuracy is:0.8965035207390304
#
#
# At random state 126,the training accuracy is:0.8971910666320126
# At random state 126,the testing accuracy is:0.8817018919404919
#
#
# At random state 127,the training accuracy is:0.9092636392127817
# At random state 127,the testing accuracy is:0.8393530076078357
#
#
# At random state 128,the training accuracy is:0.8960063173863748
# At random state 128,the testing accuracy is:0.8909334379467282
#
#
# At random state 129,the training accuracy is:0.8874722395872812
# At random state 129,the testing accuracy is:0.9315246078859212
#
#
# At random state 130,the training accuracy is:0.8984441205154504
# At random state 130,the testing accuracy is:0.8901711872699312
#
#
# At random state 131,the training accuracy is:0.8941112628895364
# At random state 131,the testing accuracy is:0.9067881287388955
#
#
# At random state 132,the training accuracy is:0.8993059709188262
# At random state 132,the testing accuracy is:0.8801637334318548
#
#
# At random state 133,the training accuracy is:0.9114967356686552
# At random state 133,the testing accuracy is:0.8118701806050487
#
#
# At random state 134,the training accuracy is:0.891224249924449
# At random state 134,the testing accuracy is:0.9153103036831862
#
#
# At random state 135,the training accuracy is:0.906741490599893
# At random state 135,the testing accuracy is:0.8603237366206004
#
#
# At random state 136,the training accuracy is:0.9095206035061183
# At random state 136,the testing accuracy is:0.8479293972659219
#
#
# At random state 137,the training accuracy is:0.8858398838919875
# At random state 137,the testing accuracy is:0.9310168278491033
#
#
# At random state 138,the training accuracy is:0.8877104777851862
# At random state 138,the testing accuracy is:0.9181165486610512
#
#
# At random state 139,the training accuracy is:0.8772670424086868
# At random state 139,the testing accuracy is:0.935246446845331
#
#
# At random state 140,the training accuracy is:0.9128022049817527
# At random state 140,the testing accuracy is:0.8249061249934686
#
#
# At random state 141,the training accuracy is:0.8912691977681884
# At random state 141,the testing accuracy is:0.9119000423058675
#
#
# At random state 142,the training accuracy is:0.8952059008341351
# At random state 142,the testing accuracy is:0.8997605292939779
#
#
# At random state 143,the training accuracy is:0.9109165223608205
# At random state 143,the testing accuracy is:0.846554167907404
#
#
# At random state 144,the training accuracy is:0.8972805828645188
# At random state 144,the testing accuracy is:0.8912291318737979
# At random state 145,the training accuracy is:0.9137361795374289
# At random state 145,the testing accuracy is:0.8223366685380756
#
#
# At random state 146,the training accuracy is:0.8965291383990815
# At random state 146,the testing accuracy is:0.8969935698010887
#
#
# At random state 147,the training accuracy is:0.9131539566963355
# At random state 147,the testing accuracy is:0.8353434745829791
#
#
# At random state 148,the training accuracy is:0.8914277127968552
# At random state 148,the testing accuracy is:0.9136660019617792
#
#
# At random state 149,the training accuracy is:0.9037333176465929
# At random state 149,the testing accuracy is:0.8603246061640323
#
#
# At random state 150,the training accuracy is:0.8890066762925594
# At random state 150,the testing accuracy is:0.9242637433246306
#
#
# At random state 151,the training accuracy is:0.8802817572915125
# At random state 151,the testing accuracy is:0.9526488497301869
#
#
# At random state 152,the training accuracy is:0.8960227787809458
# At random state 152,the testing accuracy is:0.8974767162220519
#
#
# At random state 153,the training accuracy is:0.9005227402942728
# At random state 153,the testing accuracy is:0.8789167740337055
#
#
# At random state 154,the training accuracy is:0.8853873064997979
# At random state 154,the testing accuracy is:0.935587121550672
#
#
# At random state 155,the training accuracy is:0.9192647330806977
# At random state 155,the testing accuracy is:0.8054881223837652
#
#
# At random state 156,the training accuracy is:0.8923789551779063
# At random state 156,the testing accuracy is:0.915476893860087
#
#
# At random state 157,the training accuracy is:0.9127596173992639
# At random state 157,the testing accuracy is:0.8151324992809577
#
#
# At random state 158,the training accuracy is:0.8882624373842647
# At random state 158,the testing accuracy is:0.9236992659273533
#
#
# At random state 159,the training accuracy is:0.8902746643724242
# At random state 159,the testing accuracy is:0.9120147295100955
#
#
# At random state 160,the training accuracy is:0.8984844410696912
# At random state 160,the testing accuracy is:0.8803574453164791
#
#
# At random state 161,the training accuracy is:0.8908088785272071
# At random state 161,the testing accuracy is:0.9166839926224004
#
#
# At random state 162,the training accuracy is:0.9023354162905649
# At random state 162,the testing accuracy is:0.8699645939022176
#
#
# At random state 163,the training accuracy is:0.8999391456590943
# At random state 163,the testing accuracy is:0.8770389979095079
#
#
# At random state 164,the training accuracy is:0.8779759377452452
# At random state 164,the testing accuracy is:0.9366595825687132
#
#
# At random state 165,the training accuracy is:0.9123291331196994
# At random state 165,the testing accuracy is:0.8308104977575753
#
#
# At random state 166,the training accuracy is:0.9065524233588178
# At random state 166,the testing accuracy is:0.8553131636692857
#
#
# At random state 167,the training accuracy is:0.9055314351260499
# At random state 167,the testing accuracy is:0.8598983398551017
#
#
# At random state 168,the training accuracy is:0.892938699524284
# At random state 168,the testing accuracy is:0.9072044171456553
#
#
# At random state 169,the training accuracy is:0.8954406788115592
# At random state 169,the testing accuracy is:0.8973604449224468
#
#
# At random state 170,the training accuracy is:0.9077335670572274
# At random state 170,the testing accuracy is:0.8392588150878875
#
#
# At random state 171,the training accuracy is:0.8959702245262342
# At random state 171,the testing accuracy is:0.9016397224114635
#
#
# At random state 172,the training accuracy is:0.8990904608006273
# At random state 172,the testing accuracy is:0.8848452274366015
#
#
# At random state 173,the training accuracy is:0.8916513104171098
# At random state 173,the testing accuracy is:0.9138697392160363
#
#
# At random state 174,the training accuracy is:0.8922455418927793
# At random state 174,the testing accuracy is:0.9046950271245966
#
#
# At random state 175,the training accuracy is:0.891723996689515
# At random state 175,the testing accuracy is:0.9161781413840759
#
#
# At random state 176,the training accuracy is:0.8991772292860336
# At random state 176,the testing accuracy is:0.8786777204895475
#
#
# At random state 177,the training accuracy is:0.8961987557622
# At random state 177,the testing accuracy is:0.8944309671563141
#
#
# At random state 178,the training accuracy is:0.8930967786861099
# At random state 178,the testing accuracy is:0.9152367603560009
#
#
# At random state 179,the training accuracy is:0.8915429192307247
# At random state 179,the testing accuracy is:0.9227549926685609
#
#
# At random state 180,the training accuracy is:0.8970841845747388
# At random state 180,the testing accuracy is:0.8942070035326563
#
#
# At random state 181,the training accuracy is:0.8947888505521684
# At random state 181,the testing accuracy is:0.9001609919327378
#
#
# At random state 182,the training accuracy is:0.8924253950055532
# At random state 182,the testing accuracy is:0.9177554137670092
#
#
# At random state 183,the training accuracy is:0.9072742052702495
# At random state 183,the testing accuracy is:0.8618952955924435
#
#
# At random state 184,the training accuracy is:0.9119080203164504
# At random state 184,the testing accuracy is:0.8460888287773234
#
#
# At random state 185,the training accuracy is:0.8963960987806786
# At random state 185,the testing accuracy is:0.8953997798763728
#
#
# At random state 186,the training accuracy is:0.9131318319134953
# At random state 186,the testing accuracy is:0.7951538568226986
#
#
# At random state 187,the training accuracy is:0.8783905488690263
# At random state 187,the testing accuracy is:0.9330625955504916
#
#
# At random state 188,the training accuracy is:0.8979633502272522
# At random state 188,the testing accuracy is:0.8786773701664957
#
#
# At random state 189,the training accuracy is:0.9212736464586673
# At random state 189,the testing accuracy is:0.793189905574573
#
#
# At random state 190,the training accuracy is:0.8958496132153253
# At random state 190,the testing accuracy is:0.899140693657249
#
#
# At random state 191,the training accuracy is:0.8981478028878015
# At random state 191,the testing accuracy is:0.8887339366636455
#
#
# At random state 192,the training accuracy is:0.8999065285869466
# At random state 192,the testing accuracy is:0.8703281687476143
#
#
# At random state 193,the training accuracy is:0.889729862456147
# At random state 193,the testing accuracy is:0.9297875124448732
#
#
# At random state 194,the training accuracy is:0.8887670478795503
# At random state 194,the testing accuracy is:0.9200862002188844
#
#
# At random state 195,the training accuracy is:0.9102666165559623
# At random state 195,the testing accuracy is:0.8458480899579321
#
#
# At random state 196,the training accuracy is:0.8989949259169574
# At random state 196,the testing accuracy is:0.8877807986047637
#
#
# At random state 197,the training accuracy is:0.9006661030899304
# At random state 197,the testing accuracy is:0.8830208310366645
#
#
# At random state 198,the training accuracy is:0.9017873974473097
# At random state 198,the testing accuracy is:0.8660921801821225
#
#
# At random state 199,the training accuracy is:0.9052667894031983
# At random state 199,the testing accuracy is:0.8561197404203645
#
#
# At random state 200,the training accuracy is:0.9138033847507272
# At random state 200,the testing accuracy is:0.8373374093722867
#
#
# At random state 201,the training accuracy is:0.8935470513856691
# At random state 201,the testing accuracy is:0.9038390656365664
#
#
# At random state 202,the training accuracy is:0.8864790683844054
# At random state 202,the testing accuracy is:0.9232897482883257
#
#
# At random state 203,the training accuracy is:0.8967393779541014
# At random state 203,the testing accuracy is:0.8967772550376156
#
#
# At random state 204,the training accuracy is:0.8963284475319622
# At random state 204,the testing accuracy is:0.8951235894591775
#
#
# At random state 205,the training accuracy is:0.8996700710177707
# At random state 205,the testing accuracy is:0.8816190206047242
#
#
# At random state 206,the training accuracy is:0.9081500095446488
# At random state 206,the testing accuracy is:0.8456449203112317
#
#
# At random state 207,the training accuracy is:0.8896701922839338
# At random state 207,the testing accuracy is:0.9221230015870077
#
#
# At random state 208,the training accuracy is:0.9155401081265103
# At random state 208,the testing accuracy is:0.843127819527434
#
#
# At random state 209,the training accuracy is:0.9101850654042298
# At random state 209,the testing accuracy is:0.8369107919872983
#
#
# At random state 210,the training accuracy is:0.9085173552723516
# At random state 210,the testing accuracy is:0.8441695389261252
#
#
# At random state 211,the training accuracy is:0.891872238977194
# At random state 211,the testing accuracy is:0.9144566511128659
#
#
# At random state 212,the training accuracy is:0.892208466337744
# At random state 212,the testing accuracy is:0.9224931373788339
#
#
# At random state 213,the training accuracy is:0.8951104297395703
# At random state 213,the testing accuracy is:0.9052063229477632
#
#
# At random state 214,the training accuracy is:0.8888161425868859
# At random state 214,the testing accuracy is:0.9157771323755358
#
#
# At random state 215,the training accuracy is:0.9011723803771599
# At random state 215,the testing accuracy is:0.8673285159852795
#
#
# At random state 216,the training accuracy is:0.8989231099426175
# At random state 216,the testing accuracy is:0.8713958825144666
#
#
# At random state 217,the training accuracy is:0.8866606630015675
# At random state 217,the testing accuracy is:0.9277672882734938
#
#
# At random state 218,the training accuracy is:0.8902529600655591
# At random state 218,the testing accuracy is:0.915200064107816
#
#
# At random state 219,the training accuracy is:0.8877297713526309
# At random state 219,the testing accuracy is:0.9420918428506453
#
#
# At random state 220,the training accuracy is:0.903487701325783
# At random state 220,the testing accuracy is:0.8553103376593513
# At random state 221,the training accuracy is:0.8979071531080594
# At random state 221,the testing accuracy is:0.8832674088709882
#
#
# At random state 222,the training accuracy is:0.9227395427012036
# At random state 222,the testing accuracy is:0.7925140924218883
#
#
# At random state 223,the training accuracy is:0.9059164493901112
# At random state 223,the testing accuracy is:0.8378006687692399
#
#
# At random state 224,the training accuracy is:0.9220607465040928
# At random state 224,the testing accuracy is:0.8035827265676926
#
#
# At random state 225,the training accuracy is:0.8892108205781352
# At random state 225,the testing accuracy is:0.9148768620881145
#
#
# At random state 226,the training accuracy is:0.9123432320577557
# At random state 226,the testing accuracy is:0.8450352601423615
#
#
# At random state 227,the training accuracy is:0.884871780380048
# At random state 227,the testing accuracy is:0.9261534110321981
#
#
# At random state 228,the training accuracy is:0.9098539210424011
# At random state 228,the testing accuracy is:0.8499437295824839
#
#
# At random state 229,the training accuracy is:0.886833879020016
# At random state 229,the testing accuracy is:0.9342055493404622
#
#
# At random state 230,the training accuracy is:0.9070953974165312
# At random state 230,the testing accuracy is:0.8551655421108886
#
#
# At random state 231,the training accuracy is:0.8986323067562461
# At random state 231,the testing accuracy is:0.8896583372397705
#
#
# At random state 232,the training accuracy is:0.8950382056899817
# At random state 232,the testing accuracy is:0.8971385607130548
#
#
# At random state 233,the training accuracy is:0.8930535140731902
# At random state 233,the testing accuracy is:0.9134702954551692
#
#
# At random state 234,the training accuracy is:0.8813230232242422
# At random state 234,the testing accuracy is:0.931893368727097
#
#
# At random state 235,the training accuracy is:0.9075447958550765
# At random state 235,the testing accuracy is:0.8627654899300398
#
#
# At random state 236,the training accuracy is:0.9001458834564752
# At random state 236,the testing accuracy is:0.8744019166837933
#
#
# At random state 237,the training accuracy is:0.9045010802051144
# At random state 237,the testing accuracy is:0.8535872655298709
#
#
# At random state 238,the training accuracy is:0.8952760395182295
# At random state 238,the testing accuracy is:0.9074237516727093
#
#
# At random state 239,the training accuracy is:0.8938679882904692
# At random state 239,the testing accuracy is:0.9121744677611173
#
#
# At random state 240,the training accuracy is:0.9216172401255385
# At random state 240,the testing accuracy is:0.8164523318346859
#
#
# At random state 241,the training accuracy is:0.8934483163601631
# At random state 241,the testing accuracy is:0.9089367580478829
#
#
# At random state 242,the training accuracy is:0.898337092085784
# At random state 242,the testing accuracy is:0.8862708827366331
#
#
# At random state 243,the training accuracy is:0.8930355781830346
# At random state 243,the testing accuracy is:0.9088933957156823
#
#
# At random state 244,the training accuracy is:0.901983492906819
# At random state 244,the testing accuracy is:0.8667382506596842
#
#
# At random state 245,the training accuracy is:0.9143930093786533
# At random state 245,the testing accuracy is:0.8032070464148118
#
#
# At random state 246,the training accuracy is:0.9016754694611258
# At random state 246,the testing accuracy is:0.8746837803947448
#
#
# At random state 247,the training accuracy is:0.8888889379307512
# At random state 247,the testing accuracy is:0.9245481839300462
#
#
# At random state 248,the training accuracy is:0.9099832192878803
# At random state 248,the testing accuracy is:0.8502060354624338
#
#
# At random state 249,the training accuracy is:0.8942182556181485
# At random state 249,the testing accuracy is:0.9076803593064493
#
#
# At random state 250,the training accuracy is:0.9054908021038708
# At random state 250,the testing accuracy is:0.8510879632858361
#
#
# At random state 251,the training accuracy is:0.9102927308393974
# At random state 251,the testing accuracy is:0.8285864040958385
#
#
# At random state 252,the training accuracy is:0.9012910333443699
# At random state 252,the testing accuracy is:0.8603074227531441
#
#
# At random state 253,the training accuracy is:0.8946023087180672
# At random state 253,the testing accuracy is:0.9006716815986783
#
#
# At random state 254,the training accuracy is:0.8946904521863027
# At random state 254,the testing accuracy is:0.8840866882916405
#
#
# At random state 255,the training accuracy is:0.8977908573235669
# At random state 255,the testing accuracy is:0.8901430847160722
#
#
# At random state 256,the training accuracy is:0.9045480160100837
# At random state 256,the testing accuracy is:0.8369539789490033
#
#
# At random state 257,the training accuracy is:0.895192139601228
# At random state 257,the testing accuracy is:0.9032146085708036
#
#
# At random state 258,the training accuracy is:0.8893319804115143
# At random state 258,the testing accuracy is:0.919953700944914
#
#
# At random state 259,the training accuracy is:0.893992008865434
# At random state 259,the testing accuracy is:0.9026246735598498
#
#
# At random state 260,the training accuracy is:0.8961149977541618
# At random state 260,the testing accuracy is:0.8967241856768935
#
#
# At random state 261,the training accuracy is:0.8978520194248376
# At random state 261,the testing accuracy is:0.891830684507941
#
#
# At random state 262,the training accuracy is:0.8921729339414189
# At random state 262,the testing accuracy is:0.9109542263937044
#
#
# At random state 263,the training accuracy is:0.8882432403853446
# At random state 263,the testing accuracy is:0.9268961527885381
#
#
# At random state 264,the training accuracy is:0.8993357722847977
# At random state 264,the testing accuracy is:0.8713078490318813
#
#
# At random state 265,the training accuracy is:0.9011347522925133
# At random state 265,the testing accuracy is:0.871019335252749
#
#
# At random state 266,the training accuracy is:0.9098419915906365
# At random state 266,the testing accuracy is:0.8440313231080002
#
#
# At random state 267,the training accuracy is:0.8958372785292917
# At random state 267,the testing accuracy is:0.8995716101456261
#
#
# At random state 268,the training accuracy is:0.8969854248044227
# At random state 268,the testing accuracy is:0.895359578398029
#
#
# At random state 269,the training accuracy is:0.8997656136623529
# At random state 269,the testing accuracy is:0.8823073652411952
#
#
# At random state 270,the training accuracy is:0.8943434729034755
# At random state 270,the testing accuracy is:0.904152409930754
#
#
# At random state 271,the training accuracy is:0.9092754572533669
# At random state 271,the testing accuracy is:0.8478561359588455
#
#
# At random state 272,the training accuracy is:0.9080764504677178
# At random state 272,the testing accuracy is:0.8415120354298655
#
#
# At random state 273,the training accuracy is:0.8990926679257562
# At random state 273,the testing accuracy is:0.8875906457933251
#
#
# At random state 274,the training accuracy is:0.8946691781997729
# At random state 274,the testing accuracy is:0.9012754300353217
#
#
# At random state 275,the training accuracy is:0.8926736422005781
# At random state 275,the testing accuracy is:0.9096305296669063
#
#
# At random state 276,the training accuracy is:0.8886079190294005
# At random state 276,the testing accuracy is:0.9316836613962476
#
#
# At random state 277,the training accuracy is:0.891431618206742
# At random state 277,the testing accuracy is:0.9158090842581948
#
#
# At random state 278,the training accuracy is:0.8951769377398934
# At random state 278,the testing accuracy is:0.9034285206211501
#
#
# At random state 279,the training accuracy is:0.8942744462374305
# At random state 279,the testing accuracy is:0.9083804135281685
#
#
# At random state 280,the training accuracy is:0.8972681341812246
# At random state 280,the testing accuracy is:0.8816702550234652
#
#
# At random state 281,the training accuracy is:0.8949234046004542
# At random state 281,the testing accuracy is:0.9079780424417222
#
#
# At random state 282,the training accuracy is:0.8991459372632575
# At random state 282,the testing accuracy is:0.8797806463157363
#
#
# At random state 283,the training accuracy is:0.9022398443766173
# At random state 283,the testing accuracy is:0.8553188190714425
#
#
# At random state 284,the training accuracy is:0.8871607785393489
# At random state 284,the testing accuracy is:0.926949539235367
#
#
# At random state 285,the training accuracy is:0.8895814699874498
# At random state 285,the testing accuracy is:0.9252613600459161
#
#
# At random state 286,the training accuracy is:0.8904824284484537
# At random state 286,the testing accuracy is:0.9186712956815348
#
#
# At random state 287,the training accuracy is:0.8892170953194741
# At random state 287,the testing accuracy is:0.9222024818789083
#
#
# At random state 288,the training accuracy is:0.9071715471466275
# At random state 288,the testing accuracy is:0.8615810361866225
#
#
# At random state 289,the training accuracy is:0.8879359365662899
# At random state 289,the testing accuracy is:0.9303728171909006
#
#
# At random state 290,the training accuracy is:0.889305464682199
# At random state 290,the testing accuracy is:0.91873060292153
#
#
# At random state 291,the training accuracy is:0.9036048523334761
# At random state 291,the testing accuracy is:0.8327301581373305
#
#
# At random state 292,the training accuracy is:0.926222549056551
# At random state 292,the testing accuracy is:0.7771410048172546
#
#
# At random state 293,the training accuracy is:0.895345883228466
# At random state 293,the testing accuracy is:0.8949918974047724
#
#
# At random state 294,the training accuracy is:0.8943943744163307
# At random state 294,the testing accuracy is:0.9076433264882366
#
#
# At random state 295,the training accuracy is:0.904598675192884
# At random state 295,the testing accuracy is:0.8365359788598957
#
#
# At random state 296,the training accuracy is:0.9016321772658747
# At random state 296,the testing accuracy is:0.8697871038267021
#
#
# At random state 297,the training accuracy is:0.9062810521777467
# At random state 297,the testing accuracy is:0.8559891500896499
#
#
# At random state 298,the training accuracy is:0.91928002803903
# At random state 298,the testing accuracy is:0.8013439709736121
#
#
# At random state 299,the training accuracy is:0.8950212812020348
# At random state 299,the testing accuracy is:0.8895165452320235

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)
print(r2_score(y_test,predict_test)*100)
# Out:
# 89.28781912093181

# %% [markdown]
# # Cross-validation of the model:

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.8557808905096393 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 3 the cv score is 0.8913539823868294 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 4 the cv score is 0.8858779626590164 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 5 the cv score is 0.8842777844741692 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 6 the cv score is 0.8877823078964706 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 7 the cv score is 0.8830284351379022 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 8 the cv score is 0.879505934736525 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181
#
#
# At cross fold 9 the cv score is 0.879704245100306 and accuracy score for training is -1.0325943147399395 and accuracy score for testing is 0.8928781912093181

# %% [markdown]
# Since the number of folds don't have such impact on the accuracy and cv_score.so cv=5 is selected.

# %% [markdown]
# Here we have handled the problem of the overfitting and the underfitting by checking the training and testing score.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# Best fit line is covering most of the datapoints which shows good fit of our model.

# %% [markdown]
# # Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.8899669750871062

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.8858863329447579

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 97.58186421954385
# Cross Val Score: 97.19531414016396

# %% [markdown]
# We are getting model accuracy and cross validation both as 97.3% hence model performance is good

# %%
import pickle
filename='ascp.pk1'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model=pickle.load(open('ascp.pk1','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.9758186421954385

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=['Predicted','Orginal'])

# %%
conclusion
# Out:
#                0       1      2       3       4      5       6       7   \
# Predicted  22.965  15.916  9.647  13.813  16.045  25.43  17.337  13.952
# Orginal    22.965  15.916  9.647  13.813  16.045  25.43  17.337  13.952
#
#                8       9   ...      30      31      32      33      34  \
# Predicted  11.245  16.243  ...  23.132  12.135  16.774  12.513  20.304
# Orginal    11.245  16.243  ...  23.132  12.135  16.774  12.513  20.304
#
#                35      36      37      38     39
# Predicted  15.152  11.899  11.274  22.006  7.054
# Orginal    15.152  11.899  11.274  22.006  7.054
#
# [2 rows x 40 columns]
